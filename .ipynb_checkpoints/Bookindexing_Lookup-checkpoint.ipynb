# %% [markdown]
# # Import and Configure

# %%
#!pip install isbnlib

# %%
import pandas as pd
import isbnlib as ib
from isbnlib import ISBNLibException
from bs4 import BeautifulSoup as soup
import requests
import numpy as np
import json
import textwrap
import urllib.request
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from pandas.io.json import json_normalize

# %%
## Connect to our service account
scope = ['https://spreadsheets.google.com/feeds']
credentials = ServiceAccountCredentials.from_json_keyfile_name('./cryptic-woods-276221-799aee4b4e94.json', scope)
gc = gspread.authorize(credentials)

# %%
##Get candidate data sheet from Google Drive

# %% [markdown]
# # Data Import

# %%
spreadsheet_key = '1pKS-yQT4j_JFrQ0vWbAbfeP-2iYGBTD2CP5lM9Fa-Ro'
book = gc.open_by_key(spreadsheet_key)
worksheet = book.worksheet('ISBN')
# get_all_values gives a list of rows.
allrows = worksheet.get_all_values()

labels=allrows.pop(0)
rowdict={}
rowdictkeys=[]
for i in labels:
  rowdictkeys.append(i)
allrowsT=np.transpose(allrows)
#print(allrowsT)
rowdictvalues=allrowsT
rowdict=dict(zip(rowdictkeys,rowdictvalues))
sdf=pd.DataFrame(rowdict)
sdf.head()
# Out:
#    LV Shelf Left Bedroom Shelf Other Shelf
# 0  9780143064978             1          23
# 1  9781447209225             2          43
# 2  9788190105972             3          56
# 3  9780330302296             4          77
# 4  9780143330219             5        93.5

# %%
Isbnlist=sdf['LV Shelf Left'].tolist()

# %% [markdown]
# # Lookup Functions

# %%
def getBookValsGoogleBooks(isbn="9788129300379"):

  base_api_link = "https://www.googleapis.com/books/v1/volumes?q=isbn:"

  savelist=["publishedDate","title","authors","pageCount","categories","infoLink"]
  namedik={'Author': 'Swami Ramsukhdas','Categories': 'Conduct of life','ISBN-13': '9788129300379','Published': '2010','Title': 'Be Good and Invaluable Advice','URL': 'http://books.google.com/books?id=zOUmMwEACAAJ&dq=isbn:9788129300379&hl=&source=gbs_api'}

  with urllib.request.urlopen(base_api_link + isbn) as f:
    text = f.read()
    decoded_text = text.decode("utf-8")
    obj = json.loads(decoded_text) 

    if obj["totalItems"] <= 0:
      errdict={}
      for i in namedik.keys():
        errdict[i]=""
      return errdict
        
    
    volume_info = obj["items"][0] 
    for i in savelist:
      if i not in volume_info['volumeInfo'].keys():
        volume_info['volumeInfo'][i]=''

    authors = obj["items"][0]["volumeInfo"]["authors"]

  df=pd.DataFrame.from_dict(volume_info)
  df.drop(columns=['kind','id','etag','selfLink','saleInfo','accessInfo'],inplace=True)
  df=df.transpose()
  labeltodroplist=[]

  authlist=df['authors'][0]
  df['authors'][0]=", ".join(authlist)

  if df['categories'] is not '':
    catlist=df['categories'][0]
    df['categories'][0]=", ".join(catlist)
  
  for i in range(len(df.transpose())):
    if df.columns[i] not in savelist:
      labeltodroplist.append(df.columns[i])
  df.drop(inplace=True,axis='columns',labels=labeltodroplist)
  df.rename(columns={"authors":"Author","categories":"Categories","publishedDate":"Published","title":"Title","infoLink":"URL"},inplace=True)
  #df['ISBN-13']=[(isbn)]
  df.drop(inplace=True,columns=["pageCount"])
  print(df.to_dict(orient='records')[0])
  return(df.to_dict(orient='records')[0])

# %%
def getpageISBN(isbn="9788129300379"):

  apikey="http://api.scraperapi.com?api_key=6594089066e419a8ba582146468a34af&url="
  apiurl="http://isbnsearch.org/isbn/"

  #r=requests.get(apiurl+isbn)
  #if r is "<Response [403]>":
  req=requests.get(apikey+apiurl+isbn)
  return(req)

def getbookvals(r):
  page_soup=soup(r.content,"html.parser")
  #print(page_soup.prettify())
  booklist=page_soup.findAll("div",{"class":"bookinfo"})
  if len(booklist)==0:
      return {"ISBN-13":isbn}
  page2=soup(str(booklist[0]),"html.parser")
  title=soup((str(page2.find("h1"))),"html.parser").text
  plist=page2.findAll("p")
  infol=[('Title',title)]
  for i in plist:
    vals=i.text.split(sep=": ",maxsplit=1)
    infol.append((vals[0],vals[1]))
  infodict=dict(infol)
  infodict["URL"]=str("http://isbnsearch.org/isbn/"+infodict["ISBN-13"])
  return(infodict)

# %% [markdown]
# # Lookup in Google Books and ISBN Search

# %%
infolist=[]
row={}
gRowdict={}
for i in Isbnlist:
  gRowdict=getBookValsGoogleBooks(i)
  gRowdict["ISBN-13"]=i
  infolist.append(gRowdict)

# %%
for i in range(len(infolist)):
  y=infolist[i]
  if (y["Author"] is "" and y["Title"] is ""):
    #not found in google books.
    #find in the web scraper method
    isbn=Isbnlist[i]
    rst=getpageISBN(isbn)
    l1=getbookvals(rst)
    infolist[i]=l1

# %%
df=pd.DataFrame(infolist)
df.drop(inplace=True,columns=["ISBN-10","Edition","Binding","Publisher"])
df.fillna("Not Available")
df.to_csv("./data.csv",index=False)
df

# %% [markdown]
# # Lookup on OpenLib

# %%
df=pd.read_csv("./data.csv",)
df.fillna("")
# Out:
#                                               Title                  Author  \
# 0                         The Penguin Yearbook 2009           Derek O'Brien
# 1   The Sins of the Father (The Clifton Chronicles)          Jeffrey Archer
# 2                       Practicing the Power of NOW           Eckhart Tolle
# 3                         Effective Time Management         John Eric Adair
# 4                                      Boyhood Days     Rabindranath Tagore
# 5                     Nutitive Cooking For Children     Dr Shaila Santhanam
# 6
# 7                                        Jagat Guru  Prasada Jagannadha Rao
# 8                                     Exam Warriors          Modi, Narendra
# 9                     Be Good and Invaluable Advice        Swami Ramsukhdas
# 10                                  Book Of Ram,The      Pattanaik, Devdutt
# 11                                   Bridge of Rama            Ashok Banker
# 12                              Immortals of Meluha          Amish Tripathi
# 13                                             Jaya       Devdutt Pattanaik
# 14                          The Jim Corbett Omnibus             Jim Corbett
# 15                                    Myth = Mithya       Devdutt Pattanaik
# 16
# 17
# 18                Living with the Himalayan Masters              Swami Rama
# 19                           Seven secrets of Shiva      Pattanaik, Devdutt
# 20                                             Sita       Devdutt Pattanaik
# 21
# 22                        Don't Lose Out, Work Out!          Rujuta Diwekar
# 23                                    From Xl To Xs    Payal Gidwani Tiwari
# 24                                      Eat. Delete           Pooja Makhija
# 25                        Sporting Times: 175 Years          BORIA MAJUMDAR
# 26                                            Mukti   Saraśrī Tejapārakhījī
# 27
# 28                                Scion of Ikshvaku   Amish, Amish Tripathi
# 29                                  Revolution 2020           Chetan Bhagat
# 30             Bournvita Book Of Knowledge Vols 4-6           Derek O`brien
# 31                           What Young India Wants           Chetan Bhagat
# 32                             Making India Awesome           Chetan Bhagat
# 33                      One Night @ the Call Center           Chetan Bhagat
# 34                                         2 States           Chetan Bhagat
# 35             I Steve; Steve Jobs in his own words
# 36
# 37
# 38                                 A Beautiful Mind            Sylvia Nasar
# 39                                The Da Vinci Code               Dan Brown
# 40
# 41                        Linda Goodman's Sun Signs           Linda Goodman
#
#         Published                      Categories  \
# 0            2008  Encyclopedias and dictionaries
# 1    January 2012
# 2    January 1905
# 3      2002-05-01                       Reference
# 4            2007       Biography & Autobiography
# 5      2006-01-01
# 6
# 7      2013-01-01                  Spiritual life
# 8    January 2019
# 9            2010                 Conduct of life
# 10     April 2014
# 11           2006                 Fantasy fiction
# 12           2010                         Fiction
# 13           2010            Literary Collections
# 14           1991                  Forest animals
# 15           2006                 Hindu mythology
# 16
# 17
# 18     1999-01-01                      Philosophy
# 19           2011                        Religion
# 20     2014-02-19                        Religion
# 21
# 22     2014-09-23                Health & Fitness
# 23     2010-11-01
# 24           2012
# 25      December
# 26           2008                         Courage
# 27
# 28           2015                         Fiction
# 29           2011                         Fiction
# 30   January 2007
# 31           2012                       Education
# 32        2015-08                           India
# 33     2005-01-01         Indic fiction (English)
# 34           2009         Indic fiction (English)
# 35  November 2011
# 36
# 37
# 38     2001-12-04                     Mathematics
# 39           2004             Art museum curators
# 40
# 41           1972                       Astrology
#
#                                                   URL        ISBN-13
# 0   http://books.google.com/books?id=2khyPwAACAAJ&...  9780143064978
# 1            http://isbnsearch.org/isbn/9781447209225  9781447209225
# 2            http://isbnsearch.org/isbn/9788190105972  9788190105972
# 3   http://books.google.com/books?id=DairQgAACAAJ&...  9780330302296
# 4   http://books.google.com/books?id=UWhnwlQyplEC&...  9780143330219
# 5   http://books.google.com/books?id=PzeSMwAACAAJ&...  9788174364166
# 6                                                      9788189988364
# 7   http://books.google.com/books?id=5EaPngEACAAJ&...  9788120781757
# 8            http://isbnsearch.org/isbn/9780143441502  9780143441502
# 9   http://books.google.com/books?id=zOUmMwEACAAJ&...  9788129300379
# 10           http://isbnsearch.org/isbn/9780143419907  9780143419907
# 11  http://books.google.com/books?id=gIH-sTCL1O4C&...  9780144001446
# 12  http://books.google.com/books?id=MlJyAQAACAAJ&...  9789380658742
# 13  http://books.google.com/books?id=gzN2_fu0mIYC&...  9780143104254
# 14  http://books.google.com/books?id=TaErAAAAYAAJ&...  9780195627626
# 15  http://books.google.com/books?id=W5erCDE-u60C&...  9780143099703
# 16                                                     9780007428052
# 17                                                     9788189975678
# 18  http://books.google.com/books?id=uOsw7Z6pTjAC&...  9780893891565
# 19  http://books.google.com/books?id=MfvktAEACAAJ&...  9789380658636
# 20  http://books.google.com/books?id=j5tRnwEACAAJ&...  9780143064329
# 21                                                     9788179918265
# 22  http://books.google.com/books?id=krLRswEACAAJ&...  9789383260959
# 23  http://books.google.com/books?id=mJJGYAAACAAJ&...  9788184001471
# 24  http://books.google.com/books?id=CsPsoAEACAAJ&...  9789350292341
# 25           http://isbnsearch.org/isbn/9789382299400  9789382299400
# 26  http://books.google.com/books?id=UrY_yQEACAAJ&...  9788190662789
# 27                                                     9798129107816
# 28  http://books.google.com/books?id=SbLrjgEACAAJ&...  9789385152146
# 29  http://books.google.com/books?id=d3OQpwAACAAJ&...  9788129118806
# 30           http://isbnsearch.org/isbn/9780143330240  9780143330240
# 31  http://books.google.com/books?id=FROUMwEACAAJ&...  9788129120212
# 32  http://books.google.com/books?id=kxc6jgEACAAJ&...  9788129137425
# 33  http://books.google.com/books?id=RvzcAAAACAAJ&...  9788129108180
# 34  http://books.google.com/books?id=lHkKywEACAAJ&...  9788129115300
# 35           http://isbnsearch.org/isbn/9789350292006  9789350292006
# 36                                                     9788175225602
# 37                                                     9788189906061
# 38  http://books.google.com/books?id=mVEOAAAACAAJ&...  9780743226370
# 39  http://books.google.com/books?id=KbC_uQAACAAJ&...  9780385513227
# 40                                                       76714007994
# 41  http://books.google.com/books?id=JPzCfhJE_2MC&...  9780330233903

# %%
nfdict={}
nflist=[]
for i in range(len(df['Title'])):
    if (pd.isna(df['Title'][i])):
        nfdict["index"]=i
        print(i,df["ISBN-13"][i])
        nfdict["isbn"]=df["ISBN-13"][i]
        nflist.append(nfdict)
        nfdict={}
# Out:
# 6 9788189988364
# 16 9780007428052
# 17 9788189975678
# 21 9788179918265
# 27 9798129107816
# 36 9788175225602
# 37 9788189906061
# 40 76714007994

# %%
nfinfolist=[]
infodict={}

notFound=False
namesofmeta=['Authors','Language','Publisher','Title','Year']


for i in nflist:
    isbnval=list((i.values()))[1]
    print((isbnval))
    infodict={}
    exfodict={}
   
    try:
        infodict= ib.meta(str(isbnval),service="openl")
    except ISBNLibException:
        infodict = {"ISBN-13":str(isbnval)}
        notFound=True
        for i in namesofmeta:
          infodict[i]=""
      
    if not(False):
      authname=""
      for j in infodict["Authors"]:
        if not isinstance(infodict["Authors"],str):
          authname=", ".join(j)
        else:
          authname=str(infodict["Authors"])
      exfodict["Author"]=authname
      exfodict["Title"]=infodict["Title"]
      exfodict["ISBN-13"]=infodict["ISBN-13"]
      exfodict["Published"]=infodict["Year"]
      exfodict["URL"]=""
      exfodict["Categories"]=""
      #exfodict["Publisher"]=infodict["Publisher"]
    print(exfodict)
    
    nfinfolist.append(exfodict)
# Out:
# 9788189988364
# {'Author': '', 'Title': '', 'ISBN-13': '9788189988364', 'Published': '', 'URL': '', 'Categories': ''}
# 9780007428052
# {'Author': '', 'Title': '', 'ISBN-13': '9780007428052', 'Published': '', 'URL': '', 'Categories': ''}
# 9788189975678
# {'Author': '', 'Title': '', 'ISBN-13': '9788189975678', 'Published': '', 'URL': '', 'Categories': ''}
# 9788179918265
# {'Author': '', 'Title': '', 'ISBN-13': '9788179918265', 'Published': '', 'URL': '', 'Categories': ''}
# 9798129107816
# {'Author': '', 'Title': '', 'ISBN-13': '9798129107816', 'Published': '', 'URL': '', 'Categories': ''}
# 9788175225602
# {'Author': '', 'Title': '', 'ISBN-13': '9788175225602', 'Published': '', 'URL': '', 'Categories': ''}
# 9788189906061
# {'Author': 'T, i, m, e, s,  , o, f,  , I, n, d, i, a,  , (, F, i, r, m, )', 'Title': 'Experience India', 'ISBN-13': '9788189906061', 'Published': '2007', 'URL': '', 'Categories': ''}
# 76714007994
# {'Author': '', 'Title': '', 'ISBN-13': '76714007994', 'Published': '', 'URL': '', 'Categories': ''}

# %%
nfupdatelist=[]
for i in nfinfolist:
  row=[]
  row.append(i["Title"])
  row.append(i["Author"])
  row.append(i["Published"])
  row.append(i["Categories"])
  row.append(i["URL"])
  row.append(i["ISBN-13"])
  nfupdatelist.append(row)

j=0
for i in nflist:
  index=list(i.values())[0]
  df.loc[index]=nfupdatelist[j]
  j=j+1

df
# Out:
#                                               Title  \
# 0                         The Penguin Yearbook 2009
# 1   The Sins of the Father (The Clifton Chronicles)
# 2                       Practicing the Power of NOW
# 3                         Effective Time Management
# 4                                      Boyhood Days
# 5                     Nutitive Cooking For Children
# 6
# 7                                        Jagat Guru
# 8                                     Exam Warriors
# 9                     Be Good and Invaluable Advice
# 10                                  Book Of Ram,The
# 11                                   Bridge of Rama
# 12                              Immortals of Meluha
# 13                                             Jaya
# 14                          The Jim Corbett Omnibus
# 15                                    Myth = Mithya
# 16
# 17
# 18                Living with the Himalayan Masters
# 19                           Seven secrets of Shiva
# 20                                             Sita
# 21
# 22                        Don't Lose Out, Work Out!
# 23                                    From Xl To Xs
# 24                                      Eat. Delete
# 25                        Sporting Times: 175 Years
# 26                                            Mukti
# 27
# 28                                Scion of Ikshvaku
# 29                                  Revolution 2020
# 30             Bournvita Book Of Knowledge Vols 4-6
# 31                           What Young India Wants
# 32                             Making India Awesome
# 33                      One Night @ the Call Center
# 34                                         2 States
# 35             I Steve; Steve Jobs in his own words
# 36
# 37                                 Experience India
# 38                                 A Beautiful Mind
# 39                                The Da Vinci Code
# 40
# 41                        Linda Goodman's Sun Signs
#
#                                                Author      Published  \
# 0                                       Derek O'Brien           2008
# 1                                      Jeffrey Archer   January 2012
# 2                                       Eckhart Tolle   January 1905
# 3                                     John Eric Adair     2002-05-01
# 4                                 Rabindranath Tagore           2007
# 5                                 Dr Shaila Santhanam     2006-01-01
# 6
# 7                              Prasada Jagannadha Rao     2013-01-01
# 8                                      Modi, Narendra   January 2019
# 9                                    Swami Ramsukhdas           2010
# 10                                 Pattanaik, Devdutt     April 2014
# 11                                       Ashok Banker           2006
# 12                                     Amish Tripathi           2010
# 13                                  Devdutt Pattanaik           2010
# 14                                        Jim Corbett           1991
# 15                                  Devdutt Pattanaik           2006
# 16
# 17
# 18                                         Swami Rama     1999-01-01
# 19                                 Pattanaik, Devdutt           2011
# 20                                  Devdutt Pattanaik     2014-02-19
# 21
# 22                                     Rujuta Diwekar     2014-09-23
# 23                               Payal Gidwani Tiwari     2010-11-01
# 24                                      Pooja Makhija           2012
# 25                                     BORIA MAJUMDAR      December
# 26                              Saraśrī Tejapārakhījī           2008
# 27
# 28                              Amish, Amish Tripathi           2015
# 29                                      Chetan Bhagat           2011
# 30                                      Derek O`brien   January 2007
# 31                                      Chetan Bhagat           2012
# 32                                      Chetan Bhagat        2015-08
# 33                                      Chetan Bhagat     2005-01-01
# 34                                      Chetan Bhagat           2009
# 35                                                NaN  November 2011
# 36
# 37  T, i, m, e, s,  , o, f,  , I, n, d, i, a,  , (...           2007
# 38                                       Sylvia Nasar     2001-12-04
# 39                                          Dan Brown           2004
# 40
# 41                                      Linda Goodman           1972
#
#                         Categories  \
# 0   Encyclopedias and dictionaries
# 1                              NaN
# 2                              NaN
# 3                        Reference
# 4        Biography & Autobiography
# 5                              NaN
# 6
# 7                   Spiritual life
# 8                              NaN
# 9                  Conduct of life
# 10                             NaN
# 11                 Fantasy fiction
# 12                         Fiction
# 13            Literary Collections
# 14                  Forest animals
# 15                 Hindu mythology
# 16
# 17
# 18                      Philosophy
# 19                        Religion
# 20                        Religion
# 21
# 22                Health & Fitness
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                         Courage
# 27
# 28                         Fiction
# 29                         Fiction
# 30                             NaN
# 31                       Education
# 32                           India
# 33         Indic fiction (English)
# 34         Indic fiction (English)
# 35                             NaN
# 36
# 37
# 38                     Mathematics
# 39             Art museum curators
# 40
# 41                       Astrology
#
#                                                   URL        ISBN-13
# 0   http://books.google.com/books?id=2khyPwAACAAJ&...  9780143064978
# 1            http://isbnsearch.org/isbn/9781447209225  9781447209225
# 2            http://isbnsearch.org/isbn/9788190105972  9788190105972
# 3   http://books.google.com/books?id=DairQgAACAAJ&...  9780330302296
# 4   http://books.google.com/books?id=UWhnwlQyplEC&...  9780143330219
# 5   http://books.google.com/books?id=PzeSMwAACAAJ&...  9788174364166
# 6                                                      9788189988364
# 7   http://books.google.com/books?id=5EaPngEACAAJ&...  9788120781757
# 8            http://isbnsearch.org/isbn/9780143441502  9780143441502
# 9   http://books.google.com/books?id=zOUmMwEACAAJ&...  9788129300379
# 10           http://isbnsearch.org/isbn/9780143419907  9780143419907
# 11  http://books.google.com/books?id=gIH-sTCL1O4C&...  9780144001446
# 12  http://books.google.com/books?id=MlJyAQAACAAJ&...  9789380658742
# 13  http://books.google.com/books?id=gzN2_fu0mIYC&...  9780143104254
# 14  http://books.google.com/books?id=TaErAAAAYAAJ&...  9780195627626
# 15  http://books.google.com/books?id=W5erCDE-u60C&...  9780143099703
# 16                                                     9780007428052
# 17                                                     9788189975678
# 18  http://books.google.com/books?id=uOsw7Z6pTjAC&...  9780893891565
# 19  http://books.google.com/books?id=MfvktAEACAAJ&...  9789380658636
# 20  http://books.google.com/books?id=j5tRnwEACAAJ&...  9780143064329
# 21                                                     9788179918265
# 22  http://books.google.com/books?id=krLRswEACAAJ&...  9789383260959
# 23  http://books.google.com/books?id=mJJGYAAACAAJ&...  9788184001471
# 24  http://books.google.com/books?id=CsPsoAEACAAJ&...  9789350292341
# 25           http://isbnsearch.org/isbn/9789382299400  9789382299400
# 26  http://books.google.com/books?id=UrY_yQEACAAJ&...  9788190662789
# 27                                                     9798129107816
# 28  http://books.google.com/books?id=SbLrjgEACAAJ&...  9789385152146
# 29  http://books.google.com/books?id=d3OQpwAACAAJ&...  9788129118806
# 30           http://isbnsearch.org/isbn/9780143330240  9780143330240
# 31  http://books.google.com/books?id=FROUMwEACAAJ&...  9788129120212
# 32  http://books.google.com/books?id=kxc6jgEACAAJ&...  9788129137425
# 33  http://books.google.com/books?id=RvzcAAAACAAJ&...  9788129108180
# 34  http://books.google.com/books?id=lHkKywEACAAJ&...  9788129115300
# 35           http://isbnsearch.org/isbn/9789350292006  9789350292006
# 36                                                     9788175225602
# 37                                                     9788189906061
# 38  http://books.google.com/books?id=mVEOAAAACAAJ&...  9780743226370
# 39  http://books.google.com/books?id=KbC_uQAACAAJ&...  9780385513227
# 40                                                       76714007994
# 41  http://books.google.com/books?id=JPzCfhJE_2MC&...  9780330233903

# %% [markdown]
# # Lookup on Amazon and others

# %%
def scrapeamazon(isbn="9788181479136"):
  apihead="http://api.scraperapi.com?api_key=6594089066e419a8ba582146468a34af&url="
  pageurl="https://www.amazon.com/s?k="
  r=requests.get(pageurl+isbn)
  #if (r.status_code>500):
  #  r1=requests.get(apihead+pageurl+isbn)
  #  r=r1
  page_soup=soup(r.content,"html.parser")
  datalist=page_soup.findAll("div",{"class":"sg-col-inner"})
  return(datalist)

#scrapeamazon()

# %%
def scrapeisbnsnet(isbn="9788189988364"):
  apihead="http://api.scraperapi.com?api_key=6594089066e419a8ba582146468a34af&url="
  pageurl="https://www.isbns.net/isbn/"
  r=requests.get(apihead+pageurl+isbn+"/")
  print(r.content)
  page_soup=soup(r.content,"html.parser")
  datalist=page_soup.findAll("td",{"class":"regularText"})
  return(datalist)

#datalist=scrapeisbnsnet()

# %%
df.to_csv("./output.csv",index=False)

# %%
from df2gspread import df2gspread as d2g

wks_name = 'Jupyter Manipulated Data'

d2g.upload(df, spreadsheet_key, wks_name, credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Jupyter Manipulated Data' id:1253292659>
